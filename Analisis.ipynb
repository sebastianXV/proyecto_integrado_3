# %% [markdown]
# # Cargar dataset limpio

# %%
# Importar librerías necesarias
import pandas as pd
from scipy.stats.mstats import winsorize
import numpy as np

# Configuración de visualización
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)

# URL del dataset
DATASET_URL = 'https://raw.githubusercontent.com/sebastianXV/proyecto_integrado_3/refs/heads/main/trastornos_sueno_limpio_para_analisis.csv'

# Cargar el dataset
try:
    df = pd.read_csv(DATASET_URL)
    print("Dataset cargado exitosamente.")
except Exception as e:
    print(f"Error al cargar el dataset: {e}")

df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None') # Rellenar nulos para visualización
# Out:
# Dataset cargado exitosamente.

# %% [markdown]
# GRÁFICO 1: Validación H1 (Estrés vs Sueño)

# %%
plt.subplot(1, 3, 1)
sns.regplot(
    x='Stress Level',
    y='Quality of Sleep',
    data=df,
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'red', 'linestyle': '--'}
)
plt.title('H1: Estrés vs. Calidad del Sueño (r ≈ -0.91)', fontsize=14, fontweight='bold')
plt.xlabel('Nivel de Estrés (1-10)')
plt.ylabel('Calidad del Sueño (1-10)')
#
# Out:
# Text(0, 0.5, 'Calidad del Sueño (1-10)')

# %% [markdown]
# GRÁFICO 2: Validación H2 (IMC vs Trastornos)

# %%
plt.subplot(1, 3, 2)

sns.countplot(
    x='BMI Category',
    hue='Sleep Disorder',
    data=df,
    order=['Normal','  ','Overweight','Obese'],
    palette='viridis'
)
plt.title('H2: Trastornos del Sueño por Categoría de IMC', fontsize=14, fontweight='bold')
plt.xlabel('Categoría de IMC')
plt.ylabel('Conteo de Individuos')
plt.legend(title='Trastorno', loc='upper right')

# %% [markdown]
# GRÁFICO 3: Validación H3 (Actividad vs. Sueño)

# %%
plt.subplot(1, 3, 3)
# Boxplot para mostrar la distribución de la actividad en relación con la calidad de sueño (ordinal)
sns.boxplot(
    x='Quality of Sleep',
    y='Physical Activity Level',
    data=df,
    palette='Pastel1'
)
plt.title('H3: Nivel de Actividad por Calidad de Sueño', fontsize=14, fontweight='bold')
plt.xlabel('Calidad del Sueño (Nota)')
plt.ylabel('Actividad Física (Minutos/Día)')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1920233617.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
